# %%
import xarray as xr
import netCDF4 as nc
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from satpy import Scene
from glob import glob
ds = xr.open_dataset('C:\\Users\\sripr\Downloads\\txla2_surface_2021_06_06.nc')

ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 25, Y: 190, X: 670)
# Coordinates:
#   * time     (time) datetime64[ns] 2021-06-06 2021-06-06T01:00:00 ... 2021-06-07
#     lon      (Y, X) float64 ...
#     lat      (Y, X) float64 ...
# Dimensions without coordinates: Y, X
# Data variables:
#     zeta     (time, Y, X) float32 ...
#     air_u    (time, Y, X) float32 ...
#     air_v    (time, Y, X) float32 ...
#     sustr    (time, Y, X) float32 ...
#     svstr    (time, Y, X) float32 ...
#     u        (time, Y, X) float32 ...
#     v        (time, Y, X) float32 ...
#     temp     (time, Y, X) float32 ...
#     salt     (time, Y, X) float32 ...
#     O2       (time, Y, X) float32 ...
# Attributes:
#     title:        forecast output with z-coordinate
#     institution:  Physical Oceanography Numerical Group at Texas A and M Univ...
#     history:      Created Mon Jun  7 02:26:21 2021
#     author:       DJ Kobashi d.kobashi at tamu.edu
#     source:       ROMS 3.7
# ...

# %%
ds['temp'].isel(time=7).plot(x='lon', y='lat')

# %%
plt.plot(ds['time'], ds['temp'][:,0,0])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.title('Sea Water Temperature 2021-06-06')
plt.ylabel("Degrees Celsius")
plt.xlabel("Hours")
# Out:
# Text(0.5, -16.394669843252032, 'Hours')

# %%
import netCDF4 as nc
ds1= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_01.nc")
ds2= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_02.nc")
ds3= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_03.nc")
ds4= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_04.nc")
ds5= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_05.nc")
ds6= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_06.nc")
ds7= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_07.nc")
ds8= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_08.nc")
ds9= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_09.nc")
ds10= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_10.nc")
ds11= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_11.nc")
ds12= xr.open_dataset("C:\\Users\\sripr\\Downloads\\gcoos_ioos-station-DISL-DISL_2022_12.nc")
a = ds1.indexes['time'].to_datetimeindex()
ds1
# Out:
# C:\Users\sripr\AppData\Local\Temp\ipykernel_24888\1163343622.py:14: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'julian', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   a = ds1.indexes['time'].to_datetimeindex()
# <xarray.Dataset>
# Dimensions:                                           (time: 1300, depth: 1)
# Coordinates:
#   * time                                              (time) object 2022-01-0...
#     lat                                               float32 ...
#     lon                                               float32 ...
#   * depth                                             (depth) float32 0.0
# Data variables: (12/205)
#     platform                                          |S1 ...
#     crs                                               int32 ...
# ...

# %%
fig, ax = plt.subplots(nrows=3, ncols=2)


plt.subplot(3, 2, 1)
plt.plot(a, ds1['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-01')
plt.ylabel("Degrees Celsius")
plt.xlabel("Days")



plt.subplot(3, 2, 2)
plt.plot(ds2.indexes["time"].to_datetimeindex(), ds2['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-02')
plt.xlabel("Days")

plt.subplot(3, 2, 3)
plt.plot(ds3.indexes["time"].to_datetimeindex(), ds3['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-03')
plt.ylabel("Degrees Celsius")
plt.xlabel("Days")

plt.subplot(3, 2, 4)
plt.plot(ds4.indexes["time"].to_datetimeindex(), ds4['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-04')
plt.xlabel("Days")

plt.subplot(3, 2, 5)
plt.plot(ds5.indexes["time"].to_datetimeindex(), ds5['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-05')
plt.ylabel("Degrees Celsius")
plt.xlabel("Days")

plt.subplot(3, 2, 6)
plt.plot(ds6.indexes["time"].to_datetimeindex(), ds6['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-06')
plt.xlabel("Days")


plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.3,
                    hspace=0.5)
fig.set_figheight(16)
fig.set_figwidth(16)

fig, ax = plt.subplots(nrows=3, ncols=2)



plt.subplot(3, 2, 1)
plt.plot(ds7.indexes["time"].to_datetimeindex(), ds7['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-07')
plt.ylabel("Degrees Celsius")
plt.xlabel("Days")



plt.subplot(3, 2, 2)
plt.plot(ds8.indexes["time"].to_datetimeindex(), ds8['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-08')
plt.xlabel("Days")

plt.subplot(3, 2, 3)
plt.plot(ds9.indexes["time"].to_datetimeindex(), ds9['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-09')
plt.ylabel("Degrees Celsius")
plt.xlabel("Days")

plt.subplot(3, 2, 4)
plt.plot(ds10.indexes["time"].to_datetimeindex(), ds10['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-10')
plt.xlabel("Days")

plt.subplot(3, 2, 5)
plt.plot(ds11.indexes["time"].to_datetimeindex(), ds11['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-11')
plt.ylabel("Degrees Celsius")
plt.xlabel("Days")

plt.tight_layout()
plt.subplot(3, 2, 6)
plt.plot(ds12.indexes["time"].to_datetimeindex(), ds12['sea_surface_temp_qc_1_spk'])
plt.xticks(rotation=45, ha='right')
plt.title('Sea Surface Temperature 2022-12')
plt.xlabel("Days")


plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=0.9,
                    wspace=0.3,
                    hspace=0.5)
fig.set_figheight(16)
fig.set_figwidth(16)
# Out:
# C:\Users\sripr\AppData\Local\Temp\ipykernel_24888\2853882243.py:14: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'julian', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   plt.plot(ds2.indexes["time"].to_datetimeindex(), ds2['sea_surface_temp_qc_1_spk'])
# C:\Users\sripr\AppData\Local\Temp\ipykernel_24888\2853882243.py:20: RuntimeWarning: Converting a CFTimeIndex with dates from a non-standard calendar, 'julian', to a pandas.DatetimeIndex, which uses dates from the standard calendar.  This may lead to subtle errors in operations that depend on the length of time between dates.
#   plt.plot(ds3.indexes["time"].to_datetimeindex(), ds3['sea_surface_temp_qc_1_spk'])
# ...
